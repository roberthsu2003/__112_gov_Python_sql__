# %%
#讀取names.txt
#建立file物件
file = open('names.txt',encoding='utf-8')
#讀取檔案文字
content:str = file.read()
print(content)
#關閉stream
file.close()
print(file.closed)

# %%
#with as 自動close()
with open('names.txt',encoding='utf-8') as file:
    content:str = file.read()

names:list[str] = content.split(sep='\n')
for name in names:
    print(name)

# %%
import random
random.randint(100,105)
# Out:
# 100

# %%
random.choice(names)
# Out:
# '楊少亮'

# %%
student_names:list[str] = random.choices(names,k=3)
student_names
# Out:
# ['陳倩妮', '陳建豪', '吳晴洋']

# %%
students:list[dict] = []
for student_name in student_names:
    student:dict = dict()    
    student['name'] = student_name
    student['國文'] = random.randint(50,100)
    student['英文'] = random.randint(50,100)
    student['數學'] = random.randint(50,100)
    students.append(student)
students
# Out:
# [{'name': '陳倩妮', '國文': 58, '英文': 83, '數學': 85},
#  {'name': '陳建豪', '國文': 79, '英文': 56, '數學': 93},
#  {'name': '吳晴洋', '國文': 90, '英文': 58, '數學': 52}]
