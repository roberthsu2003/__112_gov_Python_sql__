# %%
import psycopg2
conn = psycopg2.connect("")
cur = conn.cursor()
sql = '''
CREATE TABLE IF NOT EXISTS student(
	id SERIAL PRIMARY KEY,
	name VARCHAR(20),
	chinese SMALLINT,
	english SMALLINT,
	math SMALLINT
);
'''
cur.execute(sql)
conn.commit()
cur.close()
conn.close()
