# %%
import psycopg2
import os
from psycopg2 import connect
from dotenv import load_dotenv

#初始化環境變數
load_dotenv()
# Out:
# True

# %% [markdown]
# ## 建立資料表student

# %%
#使用環境變數POSTGRE_PASSWORD,取得密碼,並建立connect(連線)的實體
conn:connect = psycopg2.connect(os.environ['POSTGRE_PASSWORD'])

# 建立cursor實體,準備執行SQL
cur = conn.cursor()

sql = '''
CREATE TABLE IF NOT EXISTS student(
	id SERIAL PRIMARY KEY,
	name VARCHAR(20),
	chinese SMALLINT,
	english SMALLINT,
	math SMALLINT
);
'''

#執行sql
cur.execute(sql)

#確認SQL可以執行
conn.commit()

#關閉cursor
cur.close()

#關閉連線
conn.close()

# %% [markdown]
# ## 新增資料

# %%
#使用環境變數POSTGRE_PASSWORD,取得密碼,並建立connect(連線)的實體
conn:connect = psycopg2.connect(os.environ['POSTGRE_PASSWORD'])

# 建立cursor實體,準備執行SQL
cur = conn.cursor()

sql = '''
INSERT INTO student(name, chinese, english, math)
VALUES('張國堂',89,90,92);
'''

#執行sql
cur.execute(sql)

#確認SQL可以執行
conn.commit()

#關閉cursor
cur.close()

#關閉連線
conn.close()

# %% [markdown]
# ## 顯示資料表

# %%
#使用環境變數POSTGRE_PASSWORD,取得密碼,並建立connect(連線)的實體
conn:connect = psycopg2.connect(os.environ['POSTGRE_PASSWORD'])

# 建立cursor實體,準備執行SQL
cur = conn.cursor()

sql = '''
SELECT *
FROM student
'''

#執行sql
cur.execute(sql)

#取得資料
print(cur.fetchall())

#確認SQL可以執行
conn.commit()

#關閉cursor
cur.close()

#關閉連線
conn.close()
# Out:
# [(1, '徐國堂', 60, 72, 85), (2, '張國堂', 89, 90, 92)]
