# %%
print("Hello! Python!")
# Out:
# Hello! Python!

# %%
n = 10 #int
m = 5.0 #float
name = '徐國堂' #str
is_google = True #bool

# %%
print(n)
print(m)
print(name)
print(is_google)
# Out:
# 10
# 5.0
# 徐國堂
# True

# %%
#tuple
t1 = (1, 2, 3, 4, 5)
print(type(t1))

t2 = ('a', 'b', 'c')
t2
# Out:
# <class 'tuple'>
# ('a', 'b', 'c')

# %%
#tuple,暫時的資料
#tuple的內容不可以修改
#tuple最常使用在拆解法(拆解tuple,給變數)

name,chinese,math,english = '徐國堂',78,92,65

# %%
print(name)
print(chinese)
print(math)
print(english)
# Out:
# 徐國堂
# 78
# 92
# 65

# %%
mylist = [1, 2, 3, 4]
mylist
# Out:
# [1, 2, 3, 4]

# %%
print(type(mylist))
# Out:
# <class 'list'>
