# %%
print("Hello! Python!")
# Out:
# Hello! Python!

# %%
n = 10 #int
m = 5.0 #float
name = '徐國堂' #str
is_google = True #bool

# %%
print(n)
print(m)
print(name)
print(is_google)
# Out:
# 10
# 5.0
# 徐國堂
# True
