# %%
#自訂function,參數
def say_hello():
    print("Hello")

# %%
#呼叫function,引數值
say_hello()
# Out:
# Hello

# %%
def say_hello(name):
    print(f'Hello!{name}')

# %%
#引數值的呼叫
say_hello("徐國堂")
# Out:
# Hello!徐國堂

# %%
#引數名稱的呼叫
say_hello(name="徐國堂")
# Out:
# Hello!徐國堂
