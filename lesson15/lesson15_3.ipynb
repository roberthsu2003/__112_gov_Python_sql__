# %%
mydict:dict[str,int] = {'a1':10,'a2':20}
if 'a1' in mydict:
    print('有a1的key')
    print(mydict['a1'])
print("============")
if 'a2' in mydict:
    print("有a2的key")
    print(mydict['a2'])

if 'a3' in mydict:
    print("有a3的key")
    print(mydict['a3'])
# Out:
# 有a1的key
# 10
# ...
# 有a2的key
# 20

# %%
mydict:dict[str,int] = {}

if 'a1' not in mydict:
    mydict['a1'] = 100
   

if 'a2' not in mydict:
    mydict['a2'] = 200



if 'a3' not in mydict:
    mydict['a3'] = 300

mydict
# Out:
# {'a1': 100, 'a2': 200, 'a3': 300}
