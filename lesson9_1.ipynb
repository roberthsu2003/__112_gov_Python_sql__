# %%
#使用dictionary建立一筆資料
#建立dict的實體
student:dict[str,any] = {
    'name':'徐國堂',
    '國文':78,
    '英文':92,
    '數學':91
}
print(student['name'])
print(student['國文'])
print(student['英文'])
print(student['數學'])
# Out:
# 徐國堂
# 78
# 92
# 91

# %%
#建立list實體

values:list[int] = [10, 20, 30]
print(values[0])
print(values[1])
print(values[2])
# Out:
# 10
# 20
# 30
